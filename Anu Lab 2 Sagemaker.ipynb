# %%
#Functions

def find_max(x,y):
    if x>y:
        result=x
    else:
        result=y
    return result

# %%
def main():
    a=3
    b=2
    c=find_max(a,b)
    print(c)

# %%
main()
# Out:
# 3
